# %% [markdown]
# ## Connect to the NHANES data resource using the HPDS Adapter

# %%
library(PicSureClient)
library(PicSureHpdsLib)

adapter <- PicSureHpdsLib::BypassAdapter$new("http://pic-sure-hpds-nhanes:8080/PIC-SURE")
resource <- adapter$useResource()

# %% [markdown]
# ### A "resource" allows access to the Data Dictionary and Query Engine of the underlying  data source

# %%
resource$help()
# Out:
#         [HELP] PicSureHpdsLib::Adapter$useResource(resource_uuid)
#             $dictionary()       Used to access data dictionary of the resource
#             $query()            Used to query against data in the resource
#         [ENVIRONMENT]
#             URL: http://pic-sure-hpds-nhanes:8080/PIC-SURE/
#   Resource UUID: FALSE

# %% [markdown]
# ## Create a new query instance and use .help() to see what can be done with it

# %%
query <- resource$query()
query$help()
# Out:
#         $select()   list of data fields to return from resource for each record
#         $require()  list of data fields that must be present in all returned records
#         $filter()   list of data fields and conditions that returned records satisfy
#            [ Filter keys exert an AND relationship on returned records      ]
#            [ Categorical values have an OR relationship on their key        ]
#            [ Numerical Ranges are inclusive of their start and end points   ]
#
#         $getCount()             returns a count indicating the number of matching numbers
#         $getResults()           returns a CSV-like string containing the matching records
#         $getResultsDataFrame()  returns a pandas DataFrame containing the matching records
#         $getRunDetails()        returns details about the last run of the query
#         $getQueryCommand()      returns the JSON-formatted query request
#         $show()                 lists all current query parameters
#
#         * $getCount(), $getResults(), and $getResultsDataFrame() functions can
#         also accept options that run queries differently which might help with
#         connection timeouts. Example: myQry$getResults(async=True, timeout=60)

# %% [markdown]
# ### Use .help() to see how to add entries to the selection criteria

# %%
query$select()$help()
# Out:
#           select()$
#              add("key")            add a single column to be returned in results
#              delete("key")         delete a single column from the list of columns to return
#              show()                lists all current columns that will be returned in results
#              clear()               clears all values from the select list

# %% [markdown]
# ### Use a chained of commands on the dictionary object to include all labs in the query's selection list

# %%
lab_keys <- resource$dictionary()$find("laboratory")$keys()
query$select()$add(lab_keys)
# Out:
# No encoding supplied: defaulting to UTF-8.
# Warning message:
# In if (has.key(key, self$data) == TRUE) {: the condition has length > 1 and only the first element will be used

# %% [markdown]
# ### Use the .show() command to see what is currently selected for the query

# %%
query$show()
# Out:
# {
#     "query": {
#         "fields": [
#             "\\laboratory\\pcbs\\PCB157 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15912\\",
#             "\\laboratory\\nutrients\\trans-b-carotene(ug per dL)\\",
#             "\\laboratory\\biochemistry\\1 Creatinine (mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\33415\\",
#             "\\laboratory\\volatile compounds\\Trichloroethene (ug per cubic meter)\\",
#             "\\laboratory\\acrylamide\\Glycideamide (pmoL per G Hb)\\",
#             "\\laboratory\\pesticides\\Diaminochloroatrazine (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14586\\",
#             "\\laboratory\\nutrients\\Phytofluene(ug per dL)\\",
#             "\\laboratory\\volatile compounds\\Toluene (ug per cubic meter)\\",
#             "\\laboratory\\hormone\\Insulin: SI(pmol per L)\\",
#             "\\laboratory\\dioxins\\1,2,3,7,8,9-hxcdd (fg per g)\\",
#             "\\laboratory\\biochemistry\\Lactate dehydrogenase LDH (U per L)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.048\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21658\\",
#             "\\laboratory\\dioxins\\1,2,3,7,8-pncdd (fg per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25194\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.027\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\30763\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32443\\",
#             "\\laboratory\\volatile compounds\\Blood Dibromomethane (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34211\\",
#             "\\laboratory\\biochemistry\\Cholesterol (mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21481\\",
#             "\\laboratory\\biochemistry\\Creatinine (mg per dL)\\",
#             "\\laboratory\\allergen test\\D. Pteronyssinus IgE antibody (kU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10431\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1680\\",
#             "\\laboratory\\blood\\Basophils number\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.0071\\",
#             "\\laboratory\\pcbs\\PCB110 (ng per g)\\",
#             "\\laboratory\\pcbs\\PCB101 (ng per g)\\",
#             "\\laboratory\\nutrients\\cis-b-carotene(ug per dL)\\",
#             "\\laboratory\\phenols\\Butyl paraben (ng per ml)\\",
#             "\\laboratory\\pesticides\\Ethametsulfuron methyl (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4243\\",
#             "\\laboratory\\allergen test\\Alternaria IgE antibody (kU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29702\\",
#             "\\laboratory\\pcbs\\PCB189 (ng per g)\\",
#             "\\laboratory\\phthalates\\Mono-(2-ethyl-5-hydroxyhexyl) phthalate\\",
#             "\\laboratory\\pcbs\\PCB167 (ng per g)\\",
#             "\\laboratory\\viral infection\\Hepatitis B surface antigen\\",
#             "\\laboratory\\pesticides\\Pentachlorophenol (ug per L) result\\",
#             "\\laboratory\\hydrocarbons\\9-fluorene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\40576\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5569\\",
#             "\\laboratory\\blood\\Segmented neutrophils percent (%)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23780\\",
#             "\\laboratory\\furans\\1,2,3,7,8-pncdf (fg per g)\\",
#             "\\laboratory\\volatile compounds\\Blood Nitrobenezene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16796\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23691\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5039\\",
#             "\\laboratory\\phthalates\\",
#             "\\laboratory\\bacterial infection\\Urinary Gonorrhea\\",
#             "\\laboratory\\bacterial infection\\Clindamycin 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31824\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34476\\",
#             "\\laboratory\\allergen test\\",
#             "\\laboratory\\phthalates\\Mono-n-methyl phthalate\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25636\\",
#             "\\laboratory\\phthalates\\Mono-ethyl phthalate\\",
#             "\\laboratory\\furans\\1,2,3,6,7,8-hxcdf (fg per g)\\",
#             "\\laboratory\\pesticides\\2,5-dichlorophenol (ug per L) result\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28818\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21128\\",
#             "\\laboratory\\bacterial infection\\Penicillin 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31912\\",
#             "\\laboratory\\pcbs\\PCB199 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19360\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\36156\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\30233\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32620\\",
#             "\\laboratory\\pcbs\\PCB177 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1061\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20509\\",
#             "\\laboratory\\volatile compounds\\1,4-dichlorobenzene (ug per cubic meter)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14409\\",
#             "\\laboratory\\polyflourochemicals\\Perfluorononanoic acid\\",
#             "\\laboratory\\hydrocarbons\\4-chrysene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16884\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18652\\",
#             "\\laboratory\\volatile compounds\\Water MTBE (ng per mL)\\",
#             "\\laboratory\\acrylamide\\Acrylamide (pmoL per G Hb)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\36598\\",
#             "\\laboratory\\biochemistry\\Bone alkaline phosphotase (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6984\\",
#             "\\laboratory\\pesticides\\dichlorovnl-dimeth prop carboacid (ug per L)\\",
#             "\\laboratory\\viral infection\\HPV 06 (Merck competitive Luminex assay)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13967\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6718\\",
#             "\\laboratory\\perchlorate\\Urinary nitrate (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\37658\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6895\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32885\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32796\\",
#             "\\laboratory\\pesticides\\Mirex (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\11492\\",
#             "\\laboratory\\pesticides\\Rimsulfuron (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3182\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19802\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\41636\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17326\\",
#             "\\laboratory\\biochemistry\\Glucose, serum (mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4155\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20951\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8221\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15293\\",
#             "\\laboratory\\hormone\\Thyroid stim hormone (TSH) (IU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18034\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\46322\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\11757\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29084\\",
#             "\\laboratory\\dioxins\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17150\\",
#             "\\laboratory\\pesticides\\Metolachlor mercapturate (ug per L) result\\",
#             "\\laboratory\\pesticides\\Endrin (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18122\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\30056\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9017\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6365\\",
#             "\\laboratory\\pesticides\\3,5,6-trichloropyridinol (ug per L) result\\",
#             "\\laboratory\\pesticides\\Malathion diacid (ug per L)\\",
#             "\\laboratory\\viral infection\\HPV 16 (Merck competitive Luminex assay)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9459\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24310\\",
#             "\\laboratory\\heavy metals\\Lead, urine (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17945\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12553\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12906\\",
#             "\\laboratory\\pcbs\\PCB153 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3801\\",
#             "\\laboratory\\biochemistry\\Gamma glutamyl transferase (U per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22188\\",
#             "\\laboratory\\biochemistry\\Prostate specific antigen ratio (%)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31294\\",
#             "\\laboratory\\polyflourochemicals\\2-(N-methyl-PFOSA) acetate\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3713\\",
#             "\\laboratory\\biochemistry\\Total bilirubin (mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\39515\\",
#             "\\laboratory\\diakyl\\Diethylthiophosphate (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13790\\",
#             "\\laboratory\\dioxins\\1,2,3,4,6,7,8-hpcdd (fg per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\30675\\",
#             "\\laboratory\\hydrocarbons\\1-benzo[c] phenanthrene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\33946\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15735\\",
#             "\\laboratory\\diakyl\\Diethylphosphate (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\11227\\",
#             "\\laboratory\\cotinine\\",
#             "\\laboratory\\blood\\Eosinophils percent (%)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25459\\",
#             "\\laboratory\\pcbs\\PCB194 (ng per g)\\",
#             "\\laboratory\\pcbs\\PCB172 (ng per g)\\",
#             "\\laboratory\\volatile compounds\\Chloroform (ug per cubic meter)\\",
#             "\\laboratory\\bacterial infection\\Syphilis RPR Titer Level\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5658\\",
#             "\\laboratory\\bacterial infection\\Cefazolin 1\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.031\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16531\\",
#             "\\laboratory\\phytoestrogens\\Equol (ng per mL)\\",
#             "\\laboratory\\dioxins\\1,2,3,4,6,7,8,9-ocdd (fg per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34034\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\33150\\",
#             "\\laboratory\\biochemistry\\Phosphorus (mg per dL)\\",
#             "\\laboratory\\perchlorate\\Urine perchlorate (ug per g creatinine)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10608\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27758\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16000\\",
#             "\\laboratory\\nutrients\\trans-lycopene(ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22896\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26255\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34122\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\39603\\",
#             "\\laboratory\\pesticides\\Beta-hexachlorocyclohexane (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23072\\",
#             "\\laboratory\\nutrients\\Vitamin C (mg per dL)\\",
#             "\\laboratory\\allergen test\\Mouse IgE antibody (kU per L)\\",
#             "\\laboratory\\viral infection\\Hepatitis A Antibody (Anti-HAV)\\",
#             "\\laboratory\\heavy metals\\Mercury, inorganic (ug per L)\\",
#             "\\laboratory\\allergen test\\Aspergillus IgE antibody (kU per L)\\",
#             "\\laboratory\\hydrocarbons\\3-benz[a] anthracene (ng per L)\\",
#             "\\laboratory\\pesticides\\Propylenethio urea (ug per L)\\",
#             "\\laboratory\\diakyl\\Dimethyldithiophosphate (ug per L)\\",
#             "\\laboratory\\pesticides\\2,4,5-trichlorophenol (ug per L) result\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\38189\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4332\\",
#             "\\laboratory\\pcbs\\PCB151 (ng per g)\\",
#             "\\laboratory\\pcbs\\PCB195 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27492\\",
#             "\\laboratory\\biochemistry\\Protoporphyrin(ug per dL RBC)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26697\\",
#             "\\laboratory\\bacterial infection\\Amoxicillin k Clavulanate 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9370\\",
#             "\\laboratory\\pesticides\\Methamidaphos (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32001\\",
#             "\\laboratory\\hydrocarbons\\3-fluoranthene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7249\\",
#             "\\laboratory\\pesticides\\o,p-DDT (ng per g)\\",
#             "\\laboratory\\allergen test\\Egg IgE antibody (kU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24752\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12199\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6453\\",
#             "\\laboratory\\phytoestrogens\\Daidzein (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5216\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29437\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12288\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1768\\",
#             "\\laboratory\\blood\\Basophils percent (%)\\",
#             "\\laboratory\\perchlorate\\Perchlorate, urine (ng per mL)\\",
#             "\\laboratory\\nutrients\\cis- Lutein-Zeaxanthin(ug per dL)\\",
#             "\\laboratory\\pesticides\\Mesosulfuron methyl (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19094\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\30144\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3271\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19271\\",
#             "\\laboratory\\pcbs\\PCB183 (ng per g)\\",
#             "\\laboratory\\pcbs\\PCB170 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1945\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32531\\",
#             "\\laboratory\\volatile compounds\\Blood Styrene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28553\\",
#             "\\laboratory\\nutrients\\Retinyl stearate(ug per dL)\\",
#             "\\laboratory\\bacterial infection\\Gentamicin 1\\",
#             "\\laboratory\\pesticides\\Acetochlor mercapturate (ug per L) result\\",
#             "\\laboratory\\bacterial infection\\Chloramphenicol 1\\",
#             "\\laboratory\\biochemistry\\Bicarbonate (mmol per L)\\",
#             "\\laboratory\\pesticides\\p,p-DDT (ng per g)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.012\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\11669\\",
#             "\\laboratory\\volatile compounds\\Blood Trichloroethene (ng per mL)\\",
#             "\\laboratory\\heavy metals\\Floor, FAAS (ug per sq. ft.)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5481\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4685\\",
#             "\\laboratory\\acrylamide\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23426\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\619\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4508\\",
#             "\\laboratory\\furans\\1,2,3,4,6,7,8-hpcdf (fg per g)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.076\\",
#             "\\laboratory\\heavy metals\\Cobalt, urine (ng per mL)\\",
#             "\\laboratory\\viral infection\\CD8 counts (cells per mm3)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21393\\",
#             "\\laboratory\\pesticides\\2,4-D (ug per L) result\\",
#             "\\laboratory\\biochemistry\\Alanine aminotransferase ALT (U per L)\\",
#             "\\laboratory\\hydrocarbons\\2-benzo[c] phenanthrene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27227\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24222\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.055\\",
#             "\\laboratory\\volatile compounds\\Blood trans-1,2-Dichloroethene (ng per mL)\\",
#             "\\laboratory\\blood\\Mean platelet volume (fL)\\",
#             "\\laboratory\\allergen test\\D. Farinae IgE antibody (kU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20774\\",
#             "\\laboratory\\pcbs\\PCB180 (ng per g)\\",
#             "\\laboratory\\polybrominated ethers\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29614\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8928\\",
#             "\\laboratory\\volatile compounds\\Blood Methylene Chloride (ng per mL)\\",
#             "\\laboratory\\polyflourochemicals\\Perfluorooctane sulfonic acid\\",
#             "\\laboratory\\bacterial infection\\Levofloxacin 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1326\\",
#             "\\laboratory\\allergen test\\Rat IgE antibody (kU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\38896\\",
#             "\\laboratory\\heavy metals\\Platinum, urine (ng per mL)\\",
#             "\\laboratory\\pesticides\\Atrazine mercapturate (ug per L) result\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8133\\",
#             "\\laboratory\\allergen test\\Cockroach IgE antibody (kU per L)\\",
#             "\\laboratory\\heavy metals\\Cadmium, urine (ng per mL)\\",
#             "\\laboratory\\volatile compounds\\Benzene (ug per cubic meter)\\",
#             "\\laboratory\\furans\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4950\\",
#             "\\laboratory\\bacterial infection\\Toxoplasma (IgM)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17857\\",
#             "\\laboratory\\pesticides\\Primisulfuron methyl (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22012\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\39957\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25017\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16354\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4066\\",
#             "\\laboratory\\pesticides\\chloro-hydro-meth-chromen-one ol (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4420\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21835\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18829\\",
#             "\\laboratory\\phthalates\\Mono-n-butyl phthalate\\",
#             "\\laboratory\\pcbs\\PCB209 (ng per g)\\",
#             "\\laboratory\\pesticides\\Oxasulfuron (ug per L)\\",
#             "\\laboratory\\polyflourochemicals\\Perfluorododecanoic acid\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29879\\",
#             "\\laboratory\\nutrients\\b-cryptoxanthin(ug per dL)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.035\\",
#             "\\laboratory\\pesticides\\Oxychlordane (ng per g)\\",
#             "\\laboratory\\furans\\2,3,7,8-tcdf (fg per g)\\",
#             "\\laboratory\\polyflourochemicals\\Perfluorooctanoic acid\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\30586\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20244\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16973\\",
#             "\\laboratory\\nutrients\\a-Tocopherol(ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28288\\",
#             "\\laboratory\\biochemistry\\Transferrin receptor (mg per L)\\",
#             "\\laboratory\\heavy metals\\Urinary Monomethylacrsonic acid (ug per L)\\",
#             "\\laboratory\\biochemistry\\Osmolality (mmol per Kg)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14851\\",
#             "\\laboratory\\nutrients\\Combined Lutein-zeaxanthin (ug per dL)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.053\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\11138\\",
#             "\\laboratory\\pcbs\\PCB206 (ng per g)\\",
#             "\\laboratory\\allergen test\\Oak IgE antibody (kU per L)\\",
#             "\\laboratory\\allergen test\\Bermuda grass IgE antibody (kU per L)\\",
#             "\\laboratory\\allergen test\\Peanut IgE antibody (kU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9105\\",
#             "\\laboratory\\pesticides\\Sulfosulfuron (ug per L)\\",
#             "\\laboratory\\volatile compounds\\Water Chloroform (ng per mL)\\",
#             "\\laboratory\\dioxins\\1,2,3,4,7,8-hxcdd (fg per g)\\",
#             "\\laboratory\\volatile compounds\\Water Bromoform (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26078\\",
#             "\\laboratory\\viral infection\\Hepatitis B core antibody\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27669\\",
#             "\\laboratory\\phenols\\Urinary Bisphenol A (ng per mL)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.015\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9636\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29349\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\33857\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10962\\",
#             "\\laboratory\\bacterial infection\\Ciprofloxacin 1\\",
#             "\\laboratory\\biochemistry\\Albumin, urine (ug per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26166\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32354\\",
#             "\\laboratory\\nutrients\\Lutein(ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22630\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6188\\",
#             "\\laboratory\\volatile compounds\\m,p-Xylene (ug per cubic meter)\\",
#             "\\laboratory\\hydrocarbons\\1-chrysene (ng per L)\\",
#             "\\laboratory\\volatile compounds\\Water Dibromochloromethane (ng per mL)\\",
#             "\\laboratory\\blood\\Mean cell hemoglobin (pg)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1414\\",
#             "\\laboratory\\volatile compounds\\Blood 1,2-Dibromo-3-chloropropane(ng per mL)\\",
#             "\\laboratory\\biochemistry\\Triglycerides (mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14321\\",
#             "\\laboratory\\polybrominated ethers\\2,2,4,4,5,5-hexabromodiphenyl ether\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10873\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32973\\",
#             "\\laboratory\\viral infection\\Hepatitis D (anti-HDV)\\",
#             "\\laboratory\\nutrients\\Folate, RBC (ng per mL RBC)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19713\\",
#             "\\laboratory\\biochemistry\\Transferrin saturation (%)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.016\\",
#             "\\laboratory\\diakyl\\Dimethylphosphate (ug per L)\\",
#             "\\laboratory\\allergen test\\Dog IgE antibody (kU per L)\\",
#             "\\laboratory\\bacterial infection\\Rifampin 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\38012\\",
#             "\\laboratory\\heavy metals\\Cesium, urine (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6807\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3978\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18299\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\37835\\",
#             "\\laboratory\\nutrients\\Folate, serum (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3448\\",
#             "\\laboratory\\phthalates\\Mono-(2-ethyl-5-oxohexl) phthalate\\",
#             "\\laboratory\\viral infection\\CD4 counts (cells per mm3)\\",
#             "\\laboratory\\pesticides\\Desethyl atrazine mercapturate (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\42078\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\33327\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14940\\",
#             "\\laboratory\\polyflourochemicals\\Perfluorooctane sulfonamide\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20686\\",
#             "\\laboratory\\polybrominated ethers\\2,2,4,4,6-pentabromodiphenyl ether\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29526\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27139\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.034\\",
#             "\\laboratory\\volatile compounds\\Blood 1,4-Dichlorobenzene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Plasma glucose: SI(mmol per L)\\",
#             "\\laboratory\\biochemistry\\Blood urea nitrogen (mg per dL)\\",
#             "\\laboratory\\bacterial infection\\Toxoplasma (IgG)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.013\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\59935\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18387\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24045\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12730\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16266\\",
#             "\\laboratory\\bacterial infection\\Trichomonas Vaginalis\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10343\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23161\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3094\\",
#             "\\laboratory\\biochemistry\\Chloride (mmol per L)\\",
#             "\\laboratory\\bacterial infection\\Urinary Chlamydia\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\48797\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3359\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22454\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\45084\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25106\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\",
#             "\\laboratory\\heavy metals\\Cadmium (ug per L)\\",
#             "\\laboratory\\diakyl\\Diethyldithiophosphate (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2122\\",
#             "\\laboratory\\biochemistry\\Total length of food fast, minutes\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7160\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25548\\",
#             "\\laboratory\\bacterial infection\\S. aureus present 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34388\\",
#             "\\laboratory\\allergen test\\Birch IgE antibody (kU per L)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.014\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7691\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.078\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\43139\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17768\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19448\\",
#             "\\laboratory\\biochemistry\\Glycohemoglobin (%)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21746\\",
#             "\\laboratory\\volatile compounds\\Blood Chlorobenzene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8044\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\884\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28907\\",
#             "\\laboratory\\hydrocarbons\\2-fluorene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10520\\",
#             "\\laboratory\\volatile compounds\\Blood Bromoform (pg per mL)\\",
#             "\\laboratory\\furans\\1,2,3,4,7,8,9-hpcdf (fg per g)\\",
#             "\\laboratory\\viral infection\\Varicella antibody\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8486\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18564\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21570\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26432\\",
#             "\\laboratory\\nutrients\\Zeaxanthin(ug per dL)\\",
#             "\\laboratory\\pesticides\\Foramsulfuron (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32266\\",
#             "\\laboratory\\pcbs\\PCB28 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22542\\",
#             "\\laboratory\\pesticides\\O-methoate (ug per L)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.019\\",
#             "\\laboratory\\volatile compounds\\Blood 2,5-Dimethylfuran (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Alkaline phosphotase (U per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25990\\",
#             "\\laboratory\\phenols\\2-isopropoxyphenol (ug per L) result\\",
#             "\\laboratory\\volatile compounds\\Blood 1,2-Dichloropropane (ng per mL)\\",
#             "\\laboratory\\pesticides\\Sulfometuron methyl (ug per L)\\",
#             "\\laboratory\\nutrients\\Retinol(ug per dL)\\",
#             "\\laboratory\\biochemistry\\HDL-cholesterol (mg per dL)\\",
#             "\\laboratory\\biochemistry\\PSA. total (ng per mL)\\",
#             "\\laboratory\\heavy metals\\Urinary Arsenic acid (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8575\\",
#             "\\laboratory\\heavy metals\\Urinary Arsenous acid (ug per L)\\",
#             "\\laboratory\\volatile compounds\\Blood Hexachloroethane (ng per mL)\\",
#             "\\laboratory\\pesticides\\Triasulfuron (ug per L)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.214\\",
#             "\\laboratory\\pcbs\\PCB138 & 158 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\4862\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.037\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10785\\",
#             "\\laboratory\\phenols\\Methyl paraben (ng per ml)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17238\\",
#             "\\laboratory\\heavy metals\\Mercury, hair (ppm) MDL Version\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1149\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19625\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10696\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\35095\\",
#             "\\laboratory\\pesticides\\Carbofuranphenol (ug per L) result\\",
#             "\\laboratory\\pesticides\\Prosulfuron (ug per L)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,2-Trichloroethane (ng per mL)\\",
#             "\\laboratory\\pcbs\\PCB49 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\39780\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28730\\",
#             "\\laboratory\\volatile compounds\\Blood Carbon Tetrachloride (ng per mL)\\",
#             "\\laboratory\\phthalates\\Mono-n-octyl phthalate\\",
#             "\\laboratory\\hydrocarbons\\1-napthol (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\30410\\",
#             "\\laboratory\\heavy metals\\Floor, GFAAS (ug per sq.ft.)\\",
#             "\\laboratory\\furans\\1,2,3,7,8,9-hxcdf (fg per g)\\",
#             "\\laboratory\\hydrocarbons\\1-benzo[a] anthracene (ng per L)\\",
#             "\\laboratory\\heavy metals\\Barium, urine (ng per mL)\\",
#             "\\laboratory\\volatile compounds\\Ethylbenzene (ug per cubic meter)\\",
#             "\\laboratory\\volatile compounds\\Blood Chloroform (pg per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34564\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15028\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2210\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\42432\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13260\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18918\\",
#             "\\laboratory\\biochemistry\\LDL-cholesterol (mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15205\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29968\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2387\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8310\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15116\\",
#             "\\laboratory\\biochemistry\\Triglyceride (mg per dL)\\",
#             "\\laboratory\\heavy metals\\Molybdenum, urine (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14232\\",
#             "\\laboratory\\allergen test\\Ragweed IgE antibody (kU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\11846\\",
#             "\\laboratory\\nutrients\\Vitamin B6(Pyridoxal 5-phosphate)nmol per L\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.017\\",
#             "\\laboratory\\bacterial infection\\MRSA 1\\",
#             "\\laboratory\\biochemistry\\Potassium (mmol per L)\\",
#             "\\laboratory\\volatile compounds\\Blood Toluene (ng per mL)\\",
#             "\\laboratory\\phenols\\Propyl paraben (ng per ml)\\",
#             "\\laboratory\\biochemistry\\Aspartate aminotransferase AST (U per L)\\",
#             "\\laboratory\\phenols\\Urinary 4-tert-octyl phenol (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Ferritin(ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\11050\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9901\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15647\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1503\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24398\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24487\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12022\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,2,2-Tetrachloroethane (ng per mL)\\",
#             "\\laboratory\\polyflourochemicals\\Perfluoroheptanoic acid\\",
#             "\\laboratory\\heavy metals\\",
#             "\\laboratory\\allergen test\\Serum total IgE antibody (kU per L)\\",
#             "\\laboratory\\hydrocarbons\\3-benzo[c] phenanthrene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21923\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\38542\\",
#             "\\laboratory\\allergen test\\Rye grass IgE antibody (kU per L)\\",
#             "\\laboratory\\nutrients\\d-Tocopherol(ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\36863\\",
#             "\\laboratory\\phytoestrogens\\Genistein (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5923\\",
#             "\\laboratory\\pcbs\\3,3,4,4,5,5-hxcb (fg per g)\\",
#             "\\laboratory\\bacterial infection\\Toxoplasma (Dye)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13702\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9812\\",
#             "\\laboratory\\bacterial infection\\Rubella international units\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\36951\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\45614\\",
#             "\\laboratory\\blood\\MCHC (g per dL)\\",
#             "\\laboratory\\pesticides\\Bensulfuron methyl (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1856\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.018\\",
#             "\\laboratory\\biochemistry\\N-Telopeptides (nmol BCE)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16089\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12641\\",
#             "\\laboratory\\viral infection\\Hepatitis C antibody (confirmed)\\",
#             "\\laboratory\\biochemistry\\Total protein (g per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17503\\",
#             "\\laboratory\\heavy metals\\Tungsten, urine (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31028\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8663\\",
#             "\\laboratory\\bacterial infection\\Trimethoprim Sulfamethoxazole 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23868\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31205\\",
#             "\\laboratory\\phthalates\\Mono-(2-ethyl)-hexyl phthalate\\",
#             "\\laboratory\\nutrients\\Phytoene(ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34918\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29791\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22365\\",
#             "\\laboratory\\heavy metals\\Lead (ug per dL)\\",
#             "\\laboratory\\hormone\\Follicle stimulating hormone (mIU per mL)\\",
#             "\\laboratory\\volatile compounds\\Blood Dibromochloromethane (pg per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23956\\",
#             "\\laboratory\\hydrocarbons\\2-phenanthrene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\796\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7337\\",
#             "\\laboratory\\phthalates\\Mono-isobutyl phthalate\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\33504\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24664\\",
#             "\\laboratory\\bacterial infection\\Enterotoxin A\\",
#             "\\laboratory\\biochemistry\\PSA, free (ng per mL)\\",
#             "\\laboratory\\perchlorate\\Nitrate, water (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31647\\",
#             "\\laboratory\\polybrominated ethers\\2,2,3,4,4-pentabromodiphenyl ether\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.061\\",
#             "\\laboratory\\biochemistry\\Fibrinogen (mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22984\\",
#             "\\laboratory\\biochemistry\\C-peptide: SI(nmol per L)\\",
#             "\\laboratory\\polyflourochemicals\\Perfluorobutane sulfonic acid\\",
#             "\\laboratory\\biochemistry\\Two Hour Glucose(OGTT) (mg per dL)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1-Dichloroethene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19183\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\1238\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25371\\",
#             "\\laboratory\\nutrients\\Total (cis- and trans-)Lycopene (ug per dL)\\",
#             "\\laboratory\\viral infection\\HPV 18 (Merck competitive Luminex assay)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20067\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27846\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32089\\",
#             "\\laboratory\\volatile compounds\\Blood o-Xylene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3890\\",
#             "\\laboratory\\nutrients\\g-tocopherol(ug per dL)\\",
#             "\\laboratory\\hormone\\",
#             "\\laboratory\\nutrients\\Vitamin B12, serum (pg per mL)\\",
#             "\\laboratory\\hydrocarbons\\6-chrysene (ng per L)\\",
#             "\\laboratory\\hydrocarbons\\3-phenanthrene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14498\\",
#             "\\laboratory\\pesticides\\2,4-dichlorophenol (ug per L) result\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23338\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20155\\",
#             "\\laboratory\\bacterial infection\\Enterotoxin B\\",
#             "\\laboratory\\biochemistry\\C-reactive protein(mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3536\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19006\\",
#             "\\laboratory\\viral infection\\Hepatitis B Surface Antibody\\",
#             "\\laboratory\\pesticides\\Gamma-hexachlorocyclohexane (ng per g)\\",
#             "\\laboratory\\bacterial infection\\Tetracycline 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27050\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26608\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\38366\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28642\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\35714\\",
#             "\\laboratory\\pesticides\\Ethylenethio urea (ug per L)\\",
#             "\\laboratory\\nutrients\\cis-Lycopene(ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34830\\",
#             "\\laboratory\\heavy metals\\Window, FAAS (ug per sq. ft.)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\47206\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.041\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5746\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13172\\",
#             "\\laboratory\\bacterial infection\\Bacterial Vaginosis\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7072\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.03\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20597\\",
#             "\\laboratory\\hydrocarbons\\4-phenanthrene (ng per L)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,3-Dichlorobenzene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19536\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\46145\\",
# ...
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13614\\",
#             "\\laboratory\\bacterial infection\\Erythromycin 1\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20420\\",
#             "\\laboratory\\volatile compounds\\Blood Ethylbenzene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12111\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\23249\\",
#             "\\laboratory\\pesticides\\4-fluoro-3-phenoxybenzoic (ug per L) acid\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\19978\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27581\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\11934\\",
#             "\\laboratory\\biochemistry\\",
#             "\\laboratory\\nutrients\\a-Cryptoxanthin(ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\34741\\",
#             "\\laboratory\\phthalates\\Mono-benzyl phthalate\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,2-Trichloroethene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26874\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7779\\",
#             "\\laboratory\\pesticides\\Metsulfuron methyl (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\707\\",
#             "\\laboratory\\pcbs\\PCB128 (ng per g)\\",
#             "\\laboratory\\heavy metals\\Mercury, total (ug per L)\\",
#             "\\laboratory\\viral infection\\HIV antibody test result\\",
#             "\\laboratory\\nutrients\\Vitamin D (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14056\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26962\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9282\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31117\\",
#             "\\laboratory\\pcbs\\3,3,4,4,5-pncb (fg per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6542\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13879\\",
#             "\\laboratory\\hydrocarbons\\1-phenanthrene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9194\\",
#             "\\laboratory\\biochemistry\\Methylmalonic acid (umol per L)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.025\\",
#             "\\laboratory\\pesticides\\Paranitrophenol (ug per L) result\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12376\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\21039\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24929\\",
#             "\\laboratory\\pcbs\\PCB74 (ng per g)\\",
#             "\\laboratory\\pcbs\\PCB52 (ng per g)\\",
#             "\\laboratory\\aging\\Telomere SD\\",
#             "\\laboratory\\blood\\White blood cell count (1000 cells per uL)\\",
#             "\\laboratory\\pesticides\\Dimethoate (ug per L)\\",
#             "\\laboratory\\bacterial infection\\Enterotoxin H\\",
#             "\\laboratory\\phytoestrogens\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5127\\",
#             "\\laboratory\\hydrocarbons\\3-benzo(a) pyrene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27316\\",
#             "\\laboratory\\pesticides\\Thifensulfuron methyl (ug per L)\\",
#             "\\laboratory\\polyflourochemicals\\Perfluorohexane sulfonic acid\\",
#             "\\laboratory\\volatile compounds\\Blood m- p-Xylene (ng per mL)\\",
#             "\\laboratory\\furans\\1,2,3,4,7,8-hxcdf (fg per g)\\",
#             "\\laboratory\\perchlorate\\Perchlorate, water (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\16177\\",
#             "\\laboratory\\bacterial infection\\Cryptosporidium (27kDA)\\",
#             "\\laboratory\\pesticides\\Nicosulfuron (ug per L)\\",
#             "\\laboratory\\biochemistry\\TIBC, Frozen Serum (ug per dL)\\",
#             "\\laboratory\\bacterial infection\\Imipenem 1\\",
#             "\\laboratory\\pesticides\\Triflusulfuron methyl (ug per L)\\",
#             "\\laboratory\\blood\\Monocyte percent (%)\\",
#             "\\laboratory\\biochemistry\\Albumin (g per dL)\\",
#             "\\laboratory\\hormone\\Thyroxine (T4) (ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15382\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.026\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22719\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\40487\\",
#             "\\laboratory\\hormone\\Luteinizing hormone (mIU per mL)\\",
#             "\\laboratory\\polybrominated ethers\\2,2,4-tribromodiphenyl ether\\",
#             "\\laboratory\\dioxins\\2,3,7,8-tcdd (fg per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10078\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\32178\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\53747\\",
#             "\\laboratory\\phthalates\\Mono(carboxynonyl) phthalate (ng per mL)\\",
#             "\\laboratory\\pesticides\\Desisopropryl atrazine (ug per L)\\",
#             "\\laboratory\\bacterial infection\\Measles\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27404\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2033\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\39073\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17592\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20862\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14674\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\10166\\",
#             "\\laboratory\\phenols\\Urinary Benzophenone-3 (ng per mL)\\",
#             "\\laboratory\\hormone\\Parathyroid Hormone(Elecys method) pg per mL\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15558\\",
#             "\\laboratory\\biochemistry\\Iron, refigerated (ug per dL)\\",
#             "\\laboratory\\melamine\\Melamine\\",
#             "\\laboratory\\heavy metals\\Urinary Arsenobetaine (ug per L)\\",
#             "\\laboratory\\blood\\Hemoglobin (g per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28023\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2475\\",
#             "\\laboratory\\viral infection\\Herpes II\\",
#             "\\laboratory\\phthalates\\Mono-(3-carboxypropyl) phthalate\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17061\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2829\\",
#             "\\laboratory\\biochemistry\\Globulin (g per dL)\\",
#             "\\laboratory\\pesticides\\Heptachlor Epoxide (ng per g)\\",
#             "\\laboratory\\volatile compounds\\Blood Benzene (ng per mL)\\",
#             "\\laboratory\\pesticides\\diethylaminomethylpyrimidinol one (ug per L)\\",
#             "\\laboratory\\blood\\Monocyte number\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28111\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22807\\",
#             "\\laboratory\\blood\\Lymphocyte percent (%)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.023\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26343\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28200\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31559\\",
#             "\\laboratory\\viral infection\\HPV 11 (Merck competitive Luminex assay)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\27934\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\45791\\",
#             "\\laboratory\\nutrients\\a-Tocopherol(umol per L)\\",
#             "\\laboratory\\nutrients\\total b-Carotene(ug per dL)\\",
#             "\\laboratory\\polybrominated ethers\\2,4,4-tribromodiphenyl ether\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\33062\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2564\\",
#             "\\laboratory\\allergen test\\Thistle IgE antibody (kU per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6630\\",
#             "\\laboratory\\polybrominated ethers\\2,2,4,4,5,5-hexabromobiphenyl\\",
#             "\\laboratory\\heavy metals\\Urinary Arsenocholine (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17680\\",
#             "\\laboratory\\pcbs\\PCB105 (ng per g)\\",
#             "\\laboratory\\pcbs\\PCB149 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13348\\",
#             "\\laboratory\\heavy metals\\Beryllium, urine (ng per mL)\\",
#             "\\laboratory\\hormone\\Insulin (uU per mL)\\",
#             "\\laboratory\\polybrominated ethers\\2,2,4,4,5-pentabromodiphenyl ether\\",
#             "\\laboratory\\volatile compounds\\Blood 1,2-Dichlorobenzene (ng per mL)\\",
#             "\\laboratory\\hydrocarbons\\2-napthol (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\31382\\",
#             "\\laboratory\\phytoestrogens\\Enterodiol (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\14144\\",
#             "\\laboratory\\bacterial infection\\Syphilis IgG EIA\\",
#             "\\laboratory\\allergen test\\Milk IgE antibody (kU per L)\\",
#             "\\laboratory\\volatile compounds\\Water Bromodichloromethane (ng per mL)\\",
#             "\\laboratory\\pesticides\\Halosulfuron (ug per L)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,2-Dichloroethane (ng per mL)\\",
#             "\\laboratory\\volatile compounds\\Blood 1,1,1-Trichloroethane (ng per mL)\\0.024\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25724\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\28376\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\24840\\",
#             "\\laboratory\\heavy metals\\Mercury, urine (ng per mL)\\",
#             "\\laboratory\\polybrominated ethers\\2,3,4,4-tetrabromodiphenyl ether\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\20332\\",
#             "\\laboratory\\heavy metals\\Thallium, urine (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Albumin, urine (mg per L)\\",
#             "\\laboratory\\perchlorate\\Iodide, water (ng per mL)\\",
#             "\\laboratory\\cotinine\\Cotinine (ng per mL)\\",
#             "\\laboratory\\nutrients\\Retinyl palmitate(ug per dL)\\",
#             "\\laboratory\\hydrocarbons\\1-pyrene (ng per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6100\\",
#             "\\laboratory\\heavy metals\\Urinary Trimethylarsine Oxide (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\25901\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7868\\",
#             "\\laboratory\\bacterial infection\\",
#             "\\laboratory\\pcbs\\PCB146 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\30498\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26520\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\6011\\",
#             "\\laboratory\\biochemistry\\Direct HDL-Cholesterol (mg per dL)\\",
#             "\\laboratory\\blood\\Hematocrit (%)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2298\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\35006\\",
#             "\\laboratory\\furans\\2,3,4,6,7,8-hxcdf (fg per g)\\",
#             "\\laboratory\\nutrients\\Iron, Frozen Serum (ug per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\38719\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (mg per dL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\17415\\",
#             "\\laboratory\\pesticides\\Hexachlorobenzene (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\8398\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\13525\\",
#             "\\laboratory\\polybrominated ethers\\2,2,4,4-tetrabromodiphenyl ether\\",
#             "\\laboratory\\polybrominated ethers\\2,2,3,4,4,5,6-heptabromodiphenyl ethr\\",
#             "\\laboratory\\biochemistry\\Homocysteine (umol per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\2740\\",
#             "\\laboratory\\volatile compounds\\Tetrachloroethene (ug per cubic meter)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\3006\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\5392\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\12818\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9547\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\33680\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7602\\",
#             "\\laboratory\\blood\\Red cell distribution width (%)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\9989\\",
#             "\\laboratory\\pcbs\\PCB156 (ng per g)\\",
#             "\\laboratory\\pesticides\\2,4,6-trichlorophenol (ug per L) result\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\26785\\",
#             "\\laboratory\\pcbs\\PCB178 (ng per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7514\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7956\\",
#             "\\laboratory\\blood\\Mean cell volume (fL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\22277\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\7426\\",
#             "\\laboratory\\pesticides\\Urinary Triclosan (ng per mL)\\",
#             "\\laboratory\\heavy metals\\Antimony, urine (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Sodium (mmol per L)\\",
#             "\\laboratory\\furans\\2,3,4,7,8-pncdf (fg per g)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\442\\",
#             "\\laboratory\\volatile compounds\\Blood cis-1,2-Dichloroethene (ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\15824\\",
#             "\\laboratory\\volatile compounds\\o-Xylene (ug per cubic meter)\\",
#             "\\laboratory\\pesticides\\Acephate (ug per L)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18476\\",
#             "\\laboratory\\phthalates\\Mono(carboxyoctyl) phthalate(ng per mL)\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\29260\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\18210\\",
#             "\\laboratory\\biochemistry\\Creatinine, urine (umol per L)\\42786\\"
#         ],
#         "requiredFields": [
#
#         ],
#         "numericFilters": {
#
#         },
#         "categoryFilters": {
#
#         },
#         "expectedResultType": "DATAFRAME"
#     }
# }

# %% [markdown]
# ### Clear the current selection list and add only "\\laboratory\\hormone\\" results

# %%
query$select()$clear()
query$select()$add(resource$dictionary()$find("\\laboratory\\hormone\\")$keys())
query$select()$show()
# Out:
# No encoding supplied: defaulting to UTF-8.
# Warning message:
# In if (has.key(key, self$data) == TRUE) {: the condition has length > 1 and only the first element will be used
# [
#     "\\laboratory\\hormone\\Follicle stimulating hormone (mIU per mL)\\",
#     "\\laboratory\\hormone\\Thyroxine (T4) (ug per dL)\\",
#     "\\laboratory\\hormone\\Parathyroid Hormone(Elecys method) pg per mL\\",
#     "\\laboratory\\hormone\\",
#     "\\laboratory\\hormone\\Insulin (uU per mL)\\",
#     "\\laboratory\\hormone\\Luteinizing hormone (mIU per mL)\\",
#     "\\laboratory\\hormone\\Thyroid stim hormone (TSH) (IU per L)\\",
#     "\\laboratory\\hormone\\Insulin: SI(pmol per L)\\"
# ]

# %% [markdown]
# ### Run some commands on the dictionary to find and then filter the query by gender

# %%
gender <- resource$dictionary()$find("sex")
gender$help()
# Out:
# No encoding supplied: defaulting to UTF-8.
#         [HELP] PicSureHpdsLib$Adapter(connection)$useResource(uuid)$dictionary()$find(term)
#             $count()        Returns the number of entries in the dictionary that match the given term
#             $keys()         Return the keys of the matching entries
#             $entries()      Return a list of matching dictionary entries
#             $DataFrame()    Return the entries in a DataFrame-compatible format
#
#         [Examples]
#             results = PicSureHpdsLib$Adapter(connection)$useResource(uuid)$dictionary()$find('asthma')
#             df = results$DataFrame()

# %%
gender$DataFrame()
# Out:
#                                                                       name
# 1 \\questionnaire\\sexual behavior\\Are you circumcised or uncircumcised\\
# 2                                                    \\demographics\\SEX\\
# 3          \\questionnaire\\sexual behavior\\Ever had sexual intercourse\\
# 4                                       \\questionnaire\\sexual behavior\\
#   categorical categoryValues observationCount HpdsDataType min   max
# 1        TRUE         No,Yes             5178   phenotypes  NA    NA
# 2        TRUE    female,male            41474   phenotypes  NA    NA
# 3        TRUE         No,Yes             8271   phenotypes  NA    NA
# 4       FALSE           <NA>            41474   phenotypes   0 17040

# %% [markdown]
# ### Add a filter on our query to filter results to only female subjects

# %%
query$filter()$help()
# Out:
#             filter()$
#               add("key", value)                  - or -
#               add("key", "value")               filter to records with KEY column that equals VALUE
#               add("key", ["value1", "value2"])  filter to records with KEY column equalling one value within the given list
#               add("key", start, end)            filter to records with KEY column value between START and END (inclusive)
#                                                     start -or- end may be set to None to filter by a max or min value
#               delete("key")                     delete a filter from the list of filters
#               show()                            lists all current filters that results records must satisfy
#               clear()                           clears all values from the filters list

# %%
query$filter()$add("\\demographics\\SEX\\", list("female"))

# %% [markdown]
# ## View our query's criterion as it currently stands

# %%
query$show()
# Out:
# {
#     "query": {
#         "fields": [
#             "\\laboratory\\hormone\\Follicle stimulating hormone (mIU per mL)\\",
#             "\\laboratory\\hormone\\Thyroxine (T4) (ug per dL)\\",
#             "\\laboratory\\hormone\\Parathyroid Hormone(Elecys method) pg per mL\\",
#             "\\laboratory\\hormone\\",
#             "\\laboratory\\hormone\\Insulin (uU per mL)\\",
#             "\\laboratory\\hormone\\Luteinizing hormone (mIU per mL)\\",
#             "\\laboratory\\hormone\\Thyroid stim hormone (TSH) (IU per L)\\",
#             "\\laboratory\\hormone\\Insulin: SI(pmol per L)\\"
#         ],
#         "requiredFields": [
#
#         ],
#         "numericFilters": {
#
#         },
#         "categoryFilters": {
#             "\\demographics\\SEX\\": [
#                 "female"
#             ]
#         },
#         "expectedResultType": "DATAFRAME"
#     }
# }

# %% [markdown]
# ### Run the query and display the results

# %%
query$help()
# Out:
#         $select()   list of data fields to return from resource for each record
#         $require()  list of data fields that must be present in all returned records
#         $filter()   list of data fields and conditions that returned records satisfy
#            [ Filter keys exert an AND relationship on returned records      ]
#            [ Categorical values have an OR relationship on their key        ]
#            [ Numerical Ranges are inclusive of their start and end points   ]
#
#         $getCount()             returns a count indicating the number of matching numbers
#         $getResults()           returns a CSV-like string containing the matching records
#         $getResultsDataFrame()  returns a pandas DataFrame containing the matching records
#         $getRunDetails()        returns details about the last run of the query
#         $getQueryCommand()      returns the JSON-formatted query request
#         $show()                 lists all current query parameters
#
#         * $getCount(), $getResults(), and $getResultsDataFrame() functions can
#         also accept options that run queries differently which might help with
#         connection timeouts. Example: myQry$getResults(async=True, timeout=60)

# %%
query$getCount()
# Out:
# No encoding supplied: defaulting to UTF-8.
# [1] 21210

# %%
query$getResultsDataFrame()
# Out:
# No encoding supplied: defaulting to UTF-8.
#       Patient.ID X.demographics.SEX. X.laboratory.hormone.
# 1              3              female                   NaN
# 2              4              female                   NaN
# 3              6              female                   NaN
# 4              8              female                   NaN
# 5             11              female                   NaN
# 6             12              female                   NaN
# 7             13              female                   0.9
# 8             14              female                   NaN
# 9             15              female                   NaN
# 10            16              female                   NaN
# 11            17              female                   NaN
# 12            19              female                   NaN
# 13            20              female                   NaN
# 14            21              female                   NaN
# 15            24              female                   NaN
# 16            25              female                   NaN
# 17            28              female                   NaN
# 18            30              female                   NaN
# 19            31              female                   NaN
# 20            32              female                   NaN
# 21            33              female                   0.3
# 22            39              female                   NaN
# 23            43              female                   NaN
# 24            45              female                   NaN
# 25            46              female                   NaN
# 26            48              female                   NaN
# 27            49              female                   NaN
# 28            50              female                  0.14
# 29            52              female                   NaN
# 30            53              female                   NaN
# ⋮              ⋮                   ⋮                     ⋮
# 21181      41418              female                   NaN
# 21182      41422              female                   NaN
# 21183      41425              female                   NaN
# 21184      41427              female                   NaN
# 21185      41430              female                   NaN
# 21186      41431              female                   NaN
# 21187      41432              female                   NaN
# 21188      41435              female                   NaN
# 21189      41438              female                   0.3
# 21190      41439              female                   NaN
# 21191      41440              female                   NaN
# 21192      41442              female                   NaN
# 21193      41443              female                   NaN
# 21194      41445              female                   NaN
# 21195      41447              female                   NaN
# 21196      41450              female                   NaN
# 21197      41451              female                   NaN
# 21198      41454              female                   NaN
# 21199      41455              female                   NaN
# 21200      41457              female                  0.14
# 21201      41458              female                   NaN
# 21202      41459              female                   NaN
# 21203      41461              female                   NaN
# 21204      41464              female                   NaN
# 21205      41466              female                   NaN
# 21206      41467              female                   NaN
# 21207      41468              female                  0.14
# 21208      41469              female                     0
# 21209      41470              female                     0
# 21210      41472              female                     0
#       X.laboratory.hormone.Follicle.stimulating.hormone..mIU.per.mL..
# 1                                                                 NaN
# 2                                                                46.1
# 3                                                                 NaN
# 4                                                               25.99
# 5                                                                 NaN
# 6                                                                 NaN
# 7                                                                 NaN
# 8                                                                 NaN
# 9                                                                 NaN
# 10                                                                NaN
# 11                                                                NaN
# 12                                                                NaN
# 13                                                                NaN
# 14                                                                NaN
# 15                                                                NaN
# 16                                                                NaN
# 17                                                                NaN
# 18                                                                NaN
# 19                                                                NaN
# 20                                                                NaN
# 21                                                                NaN
# 22                                                                NaN
# 23                                                                NaN
# 24                                                                NaN
# 25                                                                NaN
# 26                                                                NaN
# 27                                                                NaN
# 28                                                                NaN
# 29                                                                NaN
# 30                                                                NaN
# ⋮                                                                   ⋮
# 21181                                                             NaN
# 21182                                                             NaN
# 21183                                                             NaN
# 21184                                                             NaN
# 21185                                                             NaN
# 21186                                                             NaN
# 21187                                                             NaN
# 21188                                                             NaN
# 21189                                                             NaN
# 21190                                                             NaN
# 21191                                                             NaN
# 21192                                                             NaN
# 21193                                                             NaN
# 21194                                                             NaN
# 21195                                                            3.63
# 21196                                                           12.66
# 21197                                                               0
# 21198                                                               0
# 21199                                                               0
# 21200                                                               0
# 21201                                                               0
# 21202                                                               0
# 21203                                                               0
# 21204                                                               0
# 21205                                                               0
# 21206                                                               0
# 21207                                                               0
# 21208                                                               0
# 21209                                                               0
# 21210                                                               0
#       X.laboratory.hormone.Insulin..uU.per.mL..
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           8.3
# 5                                           NaN
# 6                                          7.04
# 7                                         12.92
# 8                                           NaN
# 9                                          29.5
# 10                                        15.73
# 11                                         6.07
# 12                                        14.27
# 13                                         7.43
# 14                                          NaN
# 15                                          NaN
# 16                                         8.12
# 17                                        12.13
# 18                                          NaN
# 19                                          NaN
# 20                                         8.13
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                         8.43
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                         5.26
# 29                                          NaN
# 30                                         5.64
# ⋮                                             ⋮
# 21181                                       NaN
# 21182                                       NaN
# 21183                                       NaN
# 21184                                       NaN
# 21185                                       NaN
# 21186                                       NaN
# 21187                                     14.93
# 21188                                       NaN
# 21189                                      2.17
# 21190                                       NaN
# 21191                                     11.13
# 21192                                       NaN
# 21193                                       NaN
# 21194                                       NaN
# 21195                                      16.7
# 21196                                       NaN
# 21197                                       NaN
# 21198                                       NaN
# 21199                                       NaN
# 21200                                       NaN
# 21201                                       NaN
# 21202                                       NaN
# 21203                                       NaN
# 21204                                       NaN
# 21205                                       NaN
# 21206                                      8.67
# 21207                                       NaN
# 21208                                       NaN
# 21209                                       NaN
# 21210                                      6.19
#       X.laboratory.hormone.Insulin..SI.pmol.per.L..
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                              49.8
# 5                                               NaN
# 6                                             42.24
# 7                                             77.52
# 8                                               NaN
# 9                                               NaN
# 10                                            94.38
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                            48.72
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                            48.78
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# 30                                              NaN
# ⋮                                                 ⋮
# 21181                                           NaN
# 21182                                           NaN
# 21183                                           NaN
# 21184                                           NaN
# 21185                                           NaN
# 21186                                           NaN
# 21187                                           NaN
# 21188                                           NaN
# 21189                                           NaN
# 21190                                           NaN
# 21191                                         66.78
# 21192                                           NaN
# 21193                                           NaN
# 21194                                           NaN
# 21195                                         100.2
# 21196                                           NaN
# 21197                                           NaN
# 21198                                           NaN
# 21199                                           NaN
# 21200                                           NaN
# 21201                                           NaN
# 21202                                           NaN
# 21203                                           NaN
# 21204                                           NaN
# 21205                                           NaN
# 21206                                           NaN
# 21207                                           NaN
# 21208                                           NaN
# 21209                                           NaN
# 21210                                             0
#       X.laboratory.hormone.Luteinizing.hormone..mIU.per.mL..
# 1                                                        NaN
# 2                                                      32.44
# 3                                                        NaN
# 4                                                       8.65
# 5                                                        NaN
# 6                                                        NaN
# 7                                                        NaN
# 8                                                        NaN
# 9                                                        NaN
# 10                                                       NaN
# 11                                                       NaN
# 12                                                       NaN
# 13                                                       NaN
# 14                                                       NaN
# 15                                                       NaN
# 16                                                       NaN
# 17                                                       NaN
# 18                                                       NaN
# 19                                                       NaN
# 20                                                       NaN
# 21                                                       NaN
# 22                                                       NaN
# 23                                                       NaN
# 24                                                       NaN
# 25                                                       NaN
# 26                                                       NaN
# 27                                                       NaN
# 28                                                       NaN
# 29                                                       NaN
# 30                                                       NaN
# ⋮                                                          ⋮
# 21181                                                    NaN
# 21182                                                    NaN
# 21183                                                    NaN
# 21184                                                    NaN
# 21185                                                    NaN
# 21186                                                    NaN
# 21187                                                    NaN
# 21188                                                    NaN
# 21189                                                    NaN
# 21190                                                    NaN
# 21191                                                    NaN
# 21192                                                    NaN
# 21193                                                    NaN
# 21194                                                    NaN
# 21195                                                   8.79
# 21196                                                  25.32
# 21197                                                      0
# 21198                                                      0
# 21199                                                      0
# 21200                                                      0
# 21201                                                      0
# 21202                                                      0
# 21203                                                      0
# 21204                                                      0
# 21205                                                      0
# 21206                                                      0
# 21207                                                      0
# 21208                                                      0
# 21209                                                      0
# 21210                                                      0
#       X.laboratory.hormone.Parathyroid.Hormone.Elecys.method..pg.per.mL.
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
# 5                                                                    NaN
# 6                                                                    NaN
# 7                                                                    NaN
# 8                                                                    NaN
# 9                                                                     56
# 10                                                                   NaN
# 11                                                                    33
# 12                                                                    54
# 13                                                                    56
# 14                                                                   NaN
# 15                                                                   NaN
# 16                                                                   NaN
# 17                                                                    32
# 18                                                                   NaN
# 19                                                                   NaN
# 20                                                                   NaN
# 21                                                                    27
# 22                                                                    32
# 23                                                                    33
# 24                                                                    34
# 25                                                                   NaN
# 26                                                                   NaN
# 27                                                                   NaN
# 28                                                                    15
# 29                                                                    45
# 30                                                                    29
# ⋮                                                                      ⋮
# 21181                                                                NaN
# 21182                                                                 26
# 21183                                                                NaN
# 21184                                                                NaN
# 21185                                                                NaN
# 21186                                                                NaN
# 21187                                                                 43
# 21188                                                                NaN
# 21189                                                                 27
# 21190                                                                 30
# 21191                                                                NaN
# 21192                                                                NaN
# 21193                                                                NaN
# 21194                                                                NaN
# 21195                                                                NaN
# 21196                                                                NaN
# 21197                                                                NaN
# 21198                                                                NaN
# 21199                                                                 43
# 21200                                                                 27
# 21201                                                                 60
# 21202                                                                NaN
# 21203                                                                NaN
# 21204                                                                NaN
# 21205                                                                NaN
# 21206                                                                 76
# 21207                                                                 64
# 21208                                                                NaN
# 21209                                                                 25
# 21210                                                                 30
#       X.laboratory.hormone.Thyroid.stim.hormone..TSH...IU.per.L..
# 1                                                             NaN
# 2                                                            0.85
# 3                                                             NaN
# 4                                                             2.5
# 5                                                            0.91
# 6                                                             NaN
# 7                                                             NaN
# 8                                                             NaN
# 9                                                             NaN
# 10                                                           1.88
# 11                                                            NaN
# 12                                                            NaN
# 13                                                            NaN
# 14                                                            NaN
# 15                                                            NaN
# 16                                                           0.94
# 17                                                            NaN
# 18                                                            NaN
# 19                                                           1.66
# 20                                                           4.06
# 21                                                            NaN
# 22                                                            NaN
# 23                                                            NaN
# 24                                                            NaN
# 25                                                            NaN
# 26                                                           1.31
# 27                                                            NaN
# 28                                                            NaN
# 29                                                            NaN
# 30                                                            NaN
# ⋮                                                               ⋮
# 21181                                                         NaN
# 21182                                                         NaN
# 21183                                                        0.79
# 21184                                                         NaN
# 21185                                                         NaN
# 21186                                                         NaN
# 21187                                                         NaN
# 21188                                                         NaN
# 21189                                                         NaN
# 21190                                                         NaN
# 21191                                                        0.92
# 21192                                                         NaN
# 21193                                                         NaN
# 21194                                                         NaN
# 21195                                                         NaN
# 21196                                                         NaN
# 21197                                                         NaN
# 21198                                                         NaN
# 21199                                                         NaN
# 21200                                                         NaN
# 21201                                                         NaN
# 21202                                                         NaN
# 21203                                                         NaN
# 21204                                                         NaN
# 21205                                                         NaN
# 21206                                                         NaN
# 21207                                                         NaN
# 21208                                                         NaN
# 21209                                                         NaN
# 21210                                                         NaN
#       X.laboratory.hormone.Thyroxine..T4...ug.per.dL..
# 1                                                  NaN
# 2                                                  7.8
# 3                                                  NaN
# 4                                                  7.8
# 5                                                  9.4
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 8.3
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 7.5
# 17                                                 NaN
# 18                                                 NaN
# 19                                                   7
# 20                                                 7.3
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 6.4
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# 30                                                 NaN
# ⋮                                                    ⋮
# 21181                                              NaN
# 21182                                              NaN
# 21183                                              8.1
# 21184                                              NaN
# 21185                                              NaN
# 21186                                              NaN
# 21187                                              NaN
# 21188                                              NaN
# 21189                                              NaN
# 21190                                              NaN
# 21191                                              8.5
# 21192                                              NaN
# 21193                                              NaN
# 21194                                              NaN
# 21195                                              NaN
# 21196                                              NaN
# 21197                                              NaN
# 21198                                              NaN
# 21199                                              NaN
# 21200                                              NaN
# 21201                                              NaN
# 21202                                              NaN
# 21203                                              NaN
# 21204                                              NaN
# 21205                                              NaN
# 21206                                              NaN
# 21207                                              NaN
# 21208                                              NaN
# 21209                                              NaN
# 21210                                              NaN

# %% [markdown]
# # You can even work with multiple queries at the same time without having them accidently interact with each other!

# %%
query2 <- resource$query()
query3 <- resource$query()


query2$select()$add(resource$dictionary()$find("\\demographics\\AGE")$keys())
query3$select()$add(resource$dictionary()$find("\\demographics\\AGE")$keys())


#query2$filter()$add(resource$dictionary()$find("\\demographics\\AGE").keys(), min=60)
#query3$filter()$add(resource$dictionary()$find("\\demographics\\AGE").keys(), max=20)
query2$filter()$add(resource$dictionary()$find("\\demographics\\AGE")$keys(), 60, NULL)
query3$filter()$add(resource$dictionary()$find("\\demographics\\AGE")$keys(), NULL, 20)

too_old <- query2$getResultsDataFrame()
too_young <- query3$getResultsDataFrame()
# Out:
# No encoding supplied: defaulting to UTF-8.
# No encoding supplied: defaulting to UTF-8.
# No encoding supplied: defaulting to UTF-8.
# No encoding supplied: defaulting to UTF-8.
# No encoding supplied: defaulting to UTF-8.
# No encoding supplied: defaulting to UTF-8.

# %%
too_young
# Out:
#       Patient.ID X.demographics.AGE.
# 1              3                   0
# 2              5                  18
# 3              6                   4
# 4             11                  17
# 5             19                  12
# 6             21                   2
# 7             24                   1
# 8             25                  18
# 9             29                  17
# 10            30                  19
# 11            33                  12
# 12            38                  19
# 13            40                   6
# 14            41                   0
# 15            44                   5
# 16            45                  16
# 17            46                  18
# 18            47                  17
# 19            48                  12
# 20            49                  13
# 21            51                   4
# 22            52                  11
# 23            53                  19
# 24            54                   1
# 25            56                  15
# 26            57                   3
# 27            59                  19
# 28            60                   1
# 29            61                  17
# 30            62                   8
# ⋮              ⋮                   ⋮
# 21134      41416                   2
# 21135      41417                  16
# 21136      41418                   0
# 21137      41420                   2
# 21138      41421                   6
# 21139      41422                  18
# 21140      41426                   2
# 21141      41431                   2
# 21142      41432                  13
# 21143      41433                   2
# 21144      41435                   2
# 21145      41436                   5
# 21146      41439                   9
# 21147      41440                  19
# 21148      41442                   3
# 21149      41444                  17
# 21150      41445                   1
# 21151      41446                   0
# 21152      41449                   0
# 21153      41451                   4
# 21154      41455                  15
# 21155      41457                  16
# 21156      41459                   0
# 21157      41462                  19
# 21158      41463                   8
# 21159      41464                  10
# 21160      41469                  14
# 21161      41470                  18
# 21162      41473                  18
# 21163      41474                   5

# %%
too_old
# Out:
#      Patient.ID X.demographics.AGE.
# 1             2                  85
# 2            12                  71
# 3            23                  73
# 4            27                  62
# 5            31                  72
# 6            32                  85
# 7            35                  62
# 8            37                  68
# 9            39                  80
# 10           55                  60
# 11           58                  68
# 12           64                  62
# 13           68                  84
# 14           76                  78
# 15           80                  75
# 16           81                  72
# 17           91                  60
# 18          100                  70
# 19          106                  83
# 20          109                  60
# 21          111                  60
# 22          116                  82
# 23          122                  66
# 24          127                  81
# 25          134                  65
# 26          135                  84
# 27          140                  85
# 28          144                  61
# 29          148                  66
# 30          158                  85
# ⋮             ⋮                   ⋮
# 7148      41291                  71
# 7149      41296                  69
# 7150      41303                  65
# 7151      41327                  80
# 7152      41329                  62
# 7153      41340                  61
# 7154      41354                  61
# 7155      41356                  65
# 7156      41357                  61
# 7157      41358                  62
# 7158      41360                  82
# 7159      41365                  71
# 7160      41366                  68
# 7161      41381                  68
# 7162      41382                  85
# 7163      41388                  80
# 7164      41403                  85
# 7165      41405                  70
# 7166      41406                  81
# 7167      41419                  68
# 7168      41424                  68
# 7169      41428                  62
# 7170      41441                  72
# 7171      41443                  77
# 7172      41454                  81
# 7173      41465                  61
# 7174      41466                  63
# 7175      41467                  62
# 7176      41468                  85
# 7177      41471                  71
